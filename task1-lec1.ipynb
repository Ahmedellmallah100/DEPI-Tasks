# %%
list = [1,2,3,4,5]
list.append(6)
list[1] = 10
#list.insert(1,10)
print (list)
# Out:
# [1, 10, 3, 4, 5, 6]

# %%
my_set = {'red', 'green', 'blue'}
if "green" in my_set :
    print("green is here")

my_set.add('yellow')
my_set.discard('red')
print (my_set)
# Out:
# green is here
# {'blue', 'yellow', 'green'}

# %%
set1 = set()
set1 = {1,2,3,4} 
set1.add(5)
set1.add(3)
print(set1) #it didnt change 
set1.discard(2)
print(set1)
# Out:
# {1, 2, 3, 4, 5}
# {1, 3, 4, 5}

# %%
tuple1 =(1,2,3,4,5)
tuple1 [2]
#tuple1[1] = 6 it gives an error tuple cant be modified
print(tuple1)
# Out:
# (1, 2, 3, 4, 5)

# %%
my_tuple = ('apple', 'banana', 'cherry')
my_tuple[2] 
if "banana" in my_tuple :
    print("banana is here")

print(my_tuple)
# Out:
# banana is here
# ('apple', 'banana', 'cherry')

# %%
my_list = ['apple', 'banana', 'cherry', 'date']
my_list[0]
my_list = my_list[0:3]
my_list[2] = 'grape'
print(my_list)
# Out:
# ['apple', 'banana', 'grape']

# %%
dict1 = {"name": "John" , "age": 25 , "city": "New York"}
dict1
dict1["name"]
dict1['age'] = 26
dict1['age']
dict1["job"] = "Enginner"
print (dict1)
# Out:
# {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Enginner'}

# %%
my_dict = {'brand': 'Toyota', 'model': 'Corolla', 'year': 2019}

my_dict['model'] 
del my_dict['year']
my_dict['color'] = "blue"
print(my_dict)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'color': 'blue'}
